# %%
# %matplotlib inline

from ggplot import *

ggplot(aes(x='date', y='beef'), data=meat) +\
    geom_line() +\
    stat_smooth(colour='blue', span=0.2)
# Out:
# <ggplot: (278167421)>

# %%
print meat
# Out:
#           date    beef   veal    pork  lamb_and_mutton  broilers  \
# 0   1944-01-01   751.0   85.0  1280.0             89.0       NaN
# 1   1944-02-01   713.0   77.0  1169.0             72.0       NaN
# 2   1944-03-01   741.0   90.0  1128.0             75.0       NaN
# 3   1944-04-01   650.0   89.0   978.0             66.0       NaN
# 4   1944-05-01   681.0  106.0  1029.0             78.0       NaN
# 5   1944-06-01   658.0  125.0   962.0             79.0       NaN
# 6   1944-07-01   662.0  142.0   796.0             82.0       NaN
# 7   1944-08-01   787.0  175.0   748.0             87.0       NaN
# 8   1944-09-01   774.0  182.0   678.0             91.0       NaN
# 9   1944-10-01   834.0  215.0   777.0            100.0       NaN
# 10  1944-11-01   786.0  197.0   944.0             91.0       NaN
# 11  1944-12-01   764.0  146.0  1013.0             91.0       NaN
# 12  1945-01-01   820.0  119.0  1037.0            100.0       NaN
# 13  1945-02-01   816.0   97.0   724.0             81.0       NaN
# 14  1945-03-01   836.0  107.0   723.0             87.0       NaN
# 15  1945-04-01   736.0   98.0   651.0             78.0       NaN
# 16  1945-05-01   747.0  103.0   682.0             87.0       NaN
# 17  1945-06-01   739.0  110.0   674.0             87.0       NaN
# 18  1945-07-01   736.0  117.0   610.0             82.0       NaN
# 19  1945-08-01   858.0  145.0   531.0             77.0       NaN
# 20  1945-09-01   910.0  164.0   535.0             80.0       NaN
# 21  1945-10-01  1022.0  201.0   628.0             95.0       NaN
# 22  1945-11-01   933.0  173.0   945.0             86.0       NaN
# 23  1945-12-01   783.0  118.0  1103.0             90.0       NaN
# 24  1946-01-01   856.0  101.0  1051.0             74.0       NaN
# 25  1946-02-01   827.0   85.0   966.0            109.0       NaN
# 26  1946-03-01   796.0   92.0   780.0             97.0       NaN
# 27  1946-04-01   734.0   91.0   846.0             83.0       NaN
# 28  1946-05-01   605.0   83.0   810.0             65.0       NaN
# 29  1946-06-01   461.0   78.0   505.0             75.0       NaN
# ..         ...     ...    ...     ...              ...       ...
# 797 2010-06-01  2320.0   10.7  1831.7             14.1    3139.7
# 798 2010-07-01  2229.6   10.9  1702.2             12.8    3057.7
# 799 2010-08-01  2286.6   11.2  1815.3             12.8    3200.0
# 800 2010-09-01  2252.2   11.3  1883.5             13.1    3238.3
# 801 2010-10-01  2234.9   11.4  2002.7             13.1    3183.7
# 802 2010-11-01  2235.5   11.3  2068.0             14.4    3124.4
# 803 2010-12-01  2270.9   11.7  2055.4             14.9    3175.0
# 804 2011-01-01  2122.9   10.8  1896.2             11.2    3127.5
# 805 2011-02-01  2020.4   10.5  1768.1             10.9    2852.4
# 806 2011-03-01  2266.2   12.1  2054.4             14.1    3310.4
# 807 2011-04-01  2052.5   10.2  1790.7             14.4    2973.5
# 808 2011-05-01  2131.9   10.3  1759.7             12.9    3251.1
# 809 2011-06-01  2375.0   11.2  1820.0             12.6    3284.6
# 810 2011-07-01  2134.1   10.1  1637.1             10.9    3030.9
# 811 2011-08-01  2386.9   11.4  1892.1             13.1    3330.3
# 812 2011-09-01  2215.2   10.7  1954.4             11.8    3180.4
# 813 2011-10-01  2215.1   10.6  2033.2             11.7    3096.8
# 814 2011-11-01  2148.8   10.8  2086.7             12.6    2907.1
# 815 2011-12-01  2126.3   10.8  2065.6             12.5    2855.8
# 816 2012-01-01  2113.8   10.4  1987.0             12.1    3091.8
# 817 2012-02-01  2009.0    9.8  1882.9             12.3    2954.0
# 818 2012-03-01  2159.8   10.0  1987.9             14.2    3043.7
# 819 2012-04-01  1990.6    9.9  1841.7             12.9    2993.8
# 820 2012-05-01  2232.0   10.4  1926.8             13.6    3278.0
# 821 2012-06-01  2252.1    8.9  1750.4             12.4    3105.3
# 822 2012-07-01  2200.8    9.5  1721.8             12.5    3127.0
# 823 2012-08-01  2367.5   10.1  1997.9             14.2    3317.4
# 824 2012-09-01  2016.0    8.8  1911.0             12.5    2927.1
# 825 2012-10-01  2343.7   10.3  2210.4             14.2    3335.0
# 826 2012-11-01  2206.6   10.1  2078.7             12.4    3006.7
#
#      other_chicken  turkey
# 0              NaN     NaN
# 1              NaN     NaN
# 2              NaN     NaN
# 3              NaN     NaN
# 4              NaN     NaN
# 5              NaN     NaN
# 6              NaN     NaN
# 7              NaN     NaN
# 8              NaN     NaN
# 9              NaN     NaN
# 10             NaN     NaN
# 11             NaN     NaN
# 12             NaN     NaN
# 13             NaN     NaN
# 14             NaN     NaN
# 15             NaN     NaN
# 16             NaN     NaN
# 17             NaN     NaN
# 18             NaN     NaN
# 19             NaN     NaN
# 20             NaN     NaN
# 21             NaN     NaN
# 22             NaN     NaN
# 23             NaN     NaN
# 24             NaN     NaN
# 25             NaN     NaN
# 26             NaN     NaN
# 27             NaN     NaN
# 28             NaN     NaN
# 29             NaN     NaN
# ..             ...     ...
# 797           43.7   489.5
# 798           44.9   466.9
# 799           47.5   481.1
# 800           45.6   467.1
# 801           41.0   524.3
# 802           40.3   520.5
# 803           44.1   461.4
# 804           39.8   463.0
# 805           37.4   435.6
# 806           44.1   503.1
# 807           40.3   455.6
# 808           42.9   496.4
# 809           49.3   519.3
# 810           46.2   448.1
# 811           49.9   501.3
# 812           47.0   473.2
# 813           43.4   524.5
# 814           39.8   511.4
# 815           41.4   458.9
# 816           43.2   476.7
# 817           38.8   466.8
# 818           40.1   502.1
# 819           41.6   478.0
# 820           47.7   519.9
# 821           49.2   506.6
# 822           43.4   497.2
# 823           51.0   530.1
# 824           43.7   453.1
# 825           43.8   579.9
# 826           37.5   515.3
#
# [827 rows x 8 columns]

# %%
import glob, os

theFiles = glob.glob('data/*.csv')
#print theFiles

df_list = []

for i in theFiles:
    df = pd.read_csv(i)
    
    #print df.head(10)
    df = df.T
    df.columns = ['error_rate']
    df['date'] = i.replace('data/output','').replace('.csv','')
    df['samp'] = df.index
    
    #print df.head(10)
    
#     for i in df.columns:
#         print  i
    
    df_list.append(df)

df = pd.concat(df_list)
 
df.head(45) #MAKE THIS LOOK LIKE MEAT date-and beef
# Out:
#       error_rate                 date  samp
# 1000      0.8927  2016-02-03-14-20-58  1000
# 2000      0.8960  2016-02-03-14-20-58  2000
# 4000      0.9022  2016-02-03-14-20-58  4000
# 8000      0.8977  2016-02-03-14-20-58  8000
# 1000      0.8958  2016-02-03-14-57-37  1000
# 2000      0.8946  2016-02-03-14-57-37  2000
# 4000      0.8977  2016-02-03-14-57-37  4000
# 8000      0.9020  2016-02-03-14-57-37  8000
# 1000      0.9027  2016-02-03-15-32-43  1000
# 2000      0.8969  2016-02-03-15-32-43  2000
# 4000      0.8959  2016-02-03-15-32-43  4000
# 8000      0.9048  2016-02-03-15-32-43  8000
# 1000      0.8996  2016-02-03-16-07-53  1000
# 2000      0.8943  2016-02-03-16-07-53  2000
# 4000      0.8999  2016-02-03-16-07-53  4000
# 8000      0.8981  2016-02-03-16-07-53  8000
# 1000      0.9033  2016-02-03-16-43-15  1000
# 2000      0.8968  2016-02-03-16-43-15  2000
# 4000      0.8991  2016-02-03-16-43-15  4000
# 8000      0.8945  2016-02-03-16-43-15  8000
# 1000      0.8994  2016-02-03-17-19-20  1000
# 2000      0.9019  2016-02-03-17-19-20  2000
# 4000      0.8961  2016-02-03-17-19-20  4000
# 8000      0.8964  2016-02-03-17-19-20  8000
# 1000      0.9016  2016-02-03-17-54-43  1000
# 2000      0.8984  2016-02-03-17-54-43  2000
# 4000      0.9013  2016-02-03-17-54-43  4000
# 8000      0.8977  2016-02-03-17-54-43  8000
# 1000      0.8942  2016-02-03-18-30-27  1000
# 2000      0.9012  2016-02-03-18-30-27  2000
# 4000      0.9027  2016-02-03-18-30-27  4000
# 8000      0.9010  2016-02-03-18-30-27  8000
# 1000      0.9000  2016-02-03-19-05-55  1000
# 2000      0.9012  2016-02-03-19-05-55  2000
# 4000      0.9010  2016-02-03-19-05-55  4000
# 8000      0.8997  2016-02-03-19-05-55  8000
# 1000      0.8990  2016-02-03-19-42-04  1000
# 2000      0.9016  2016-02-03-19-42-04  2000
# 4000      0.8965  2016-02-03-19-42-04  4000
# 8000      0.8995  2016-02-03-19-42-04  8000

# %%
df['count'] = 1

dfg = df.groupby(['samp'],as_index=False).sum()

dfg['error_rate'] = dfg['error_rate'] / dfg['count']

dfg.head(10)
# Out:
#    samp  error_rate  count
# 0  1000     0.89883     10
# 1  2000     0.89829     10
# 2  4000     0.89924     10
# 3  8000     0.89914     10

# %%
ggplot(aes(x='samp', y='error_rate'), data=dfg) +\
    geom_line() +\
    stat_smooth(colour='blue', span=0.3) +\
    xlab("Sample n of Training Data") + ylab("Error Rate") +\
    ggtitle("Error Rate for 1-nearest neighbor classifier with Euclidean distance")
# Out:
# <ggplot: (278667333)>

# %%
ggplot(df, aes(x = 'samp', y = 'error_rate')) + geom_point(size=50) 

#p + geom_jitter()
# Out:
# <ggplot: (280105641)>

# %%
ggplot(aes(x='samp', y='error_rate'), data=df) +\
    geom_line() +\
    stat_smooth(colour='blue', span=0.3) +\
    xlab("Sample n of Training Data") + ylab("Error Rate") +\
    ggtitle("Error Rate for 1-nearest neighbor classifier with Euclidean distance") + geom_errorbar(limits, width=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-90eb0526c26b> in <module>()
# ----> 1 ggplot(aes(x='samp', y='error_rate'), data=df) +    geom_line() +    stat_smooth(colour='blue', span=0.3) +    xlab("Sample n of Training Data") + ylab("Error Rate") +    ggtitle("Error Rate for 1-nearest neighbor classifier with Euclidean distance") + geom_errorbar(limits, width=0.2)
#
# NameError: name 'geom_errorbar' is not defined

# %%
import matplotlib.pyplot as plt
import matplotlib
#matplotlib.style.use('ggplot')

print matplotlib.__version__


gp3 = df.groupby('samp')#, 'word'))

means = gp3.mean()

errors = gp3.std()

print means


print errors

fig, ax = plt.subplots()

means.plot(yerr=errors, ax=ax, kind='bar')
# Out:
# 1.3.1
#       error_rate  count
# samp
# 1000     0.89883      1
# 2000     0.89829      1
# 4000     0.89924      1
# 8000     0.89914      1
#       error_rate  count
# samp
# 1000    0.003546      0
# 2000    0.002979      0
# 4000    0.002570      0
# 8000    0.002951      0
